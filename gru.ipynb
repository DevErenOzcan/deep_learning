# %%
import torch
import pandas as pd
from torch.utils.data import Dataset, DataLoader

class AudioDataset(Dataset):
    def __init__(self, tensors, labels):
        self.tensors = tensors  # (N, T, F) -> N örnek sayısı, T zaman adımı, F özellik boyutu
        self.labels = labels  # Speaker ID veya sınıf etiketi

    def __len__(self):
        return len(self.tensors)

    def __getitem__(self, idx):
        return self.tensors[idx], self.labels[idx]

tensors = torch.load('audio_tensors.pt')
df = pd.read_csv("processed.tsv", sep="\t")
labels = df["speaker_id"].values
dataset = AudioDataset(tensors, labels)
dataloader = DataLoader(dataset, batch_size=13, shuffle=True)
# Out:
# /tmp/ipykernel_3966/44005724.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   tensors = torch.load('audio_tensors.pt')

# %%
import torch.nn as nn

class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1):
        super(RNNModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)  # Başlangıç gizli durumu
        out, _ = self.gru(x, h0)  # (batch, seq_len, hidden_size)
        out = self.fc(out[:, -1, :])  # Son zaman adımını al ve sınıflandır
        return out

# Modeli cihaza yükle (GPU varsa kullan, yoksa CPU'yu kullan)
device = torch.device("cuda")

# Modeli oluştur ve cihaza taşı
model = RNNModel(input_size=29, hidden_size=128, output_size=64).to(device)

# %%
import torch.optim as optim
# Kayıp fonksiyonu ve optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Eğitim parametreleri
num_epochs = 100  # Kaç epoch boyunca eğitileceği
# Eğitim döngüsü
for epoch in range(num_epochs):
    total_loss = 0.0
    correct = 0
    total = 0

    model.train()  # Modeli eğitim moduna al

    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)  # Verileri cihaza taşı

        # Verileri uygun şekle getir (batch_size, seq_len, input_size)
        inputs = inputs.view(inputs.size(0), 313, 29)  # (batch, seq_length, feature_size)

        optimizer.zero_grad()  # Gradients'i sıfırla
        outputs = model(inputs)  # Modeli ileri besle

        loss = criterion(outputs, labels)  # Kayıp hesapla
        loss.backward()  # Geri yayılım (backpropagation)
        optimizer.step()  # Ağırlıkları güncelle

        total_loss += loss.item()

        # Doğruluk hesapla
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(dataloader)
    accuracy = 100 * correct / total

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%")

print("Eğitim tamamlandı!")
# Out:
# Epoch [1/100], Loss: 0.1137, Accuracy: 99.28%
# Epoch [2/100], Loss: 0.1769, Accuracy: 97.83%
# Epoch [3/100], Loss: 0.1479, Accuracy: 97.10%
# Epoch [4/100], Loss: 0.1922, Accuracy: 97.10%
# Epoch [5/100], Loss: 0.2432, Accuracy: 97.83%
# Epoch [6/100], Loss: 0.2548, Accuracy: 93.48%
# Epoch [7/100], Loss: 0.1859, Accuracy: 95.65%
# Epoch [8/100], Loss: 0.1750, Accuracy: 97.83%
# Epoch [9/100], Loss: 0.1140, Accuracy: 100.00%
# Epoch [10/100], Loss: 0.1262, Accuracy: 98.55%
# Epoch [11/100], Loss: 0.1249, Accuracy: 98.55%
# Epoch [12/100], Loss: 0.1120, Accuracy: 100.00%
# Epoch [13/100], Loss: 0.1010, Accuracy: 100.00%
# Epoch [14/100], Loss: 0.0842, Accuracy: 100.00%
# Epoch [15/100], Loss: 0.0751, Accuracy: 100.00%
# Epoch [16/100], Loss: 0.0810, Accuracy: 99.28%
# Epoch [17/100], Loss: 0.0737, Accuracy: 100.00%
# Epoch [18/100], Loss: 0.0665, Accuracy: 100.00%
# Epoch [19/100], Loss: 0.0624, Accuracy: 100.00%
# Epoch [20/100], Loss: 0.0572, Accuracy: 100.00%
# Epoch [21/100], Loss: 0.0551, Accuracy: 100.00%
# Epoch [22/100], Loss: 0.0547, Accuracy: 100.00%
# Epoch [23/100], Loss: 0.0511, Accuracy: 100.00%
# Epoch [24/100], Loss: 0.0492, Accuracy: 100.00%
# Epoch [25/100], Loss: 0.0487, Accuracy: 100.00%
# Epoch [26/100], Loss: 0.0469, Accuracy: 100.00%
# Epoch [27/100], Loss: 0.0451, Accuracy: 100.00%
# Epoch [28/100], Loss: 0.0446, Accuracy: 100.00%
# Epoch [29/100], Loss: 0.0408, Accuracy: 100.00%
# Epoch [30/100], Loss: 0.0403, Accuracy: 100.00%
# Epoch [31/100], Loss: 0.0390, Accuracy: 100.00%
# Epoch [32/100], Loss: 0.0382, Accuracy: 100.00%
# Epoch [33/100], Loss: 0.0399, Accuracy: 100.00%
# Epoch [34/100], Loss: 0.0369, Accuracy: 100.00%
# Epoch [35/100], Loss: 0.0363, Accuracy: 100.00%
# Epoch [36/100], Loss: 0.0351, Accuracy: 100.00%
# Epoch [37/100], Loss: 0.0334, Accuracy: 100.00%
# Epoch [38/100], Loss: 0.0336, Accuracy: 100.00%
# Epoch [39/100], Loss: 0.0327, Accuracy: 100.00%
# Epoch [40/100], Loss: 0.0316, Accuracy: 100.00%
# Epoch [41/100], Loss: 0.0302, Accuracy: 100.00%
# Epoch [42/100], Loss: 0.0299, Accuracy: 100.00%
# Epoch [43/100], Loss: 0.0298, Accuracy: 100.00%
# Epoch [44/100], Loss: 0.0292, Accuracy: 100.00%
# Epoch [45/100], Loss: 0.0276, Accuracy: 100.00%
# Epoch [46/100], Loss: 0.0288, Accuracy: 100.00%
# Epoch [47/100], Loss: 0.0295, Accuracy: 100.00%
# Epoch [48/100], Loss: 0.0272, Accuracy: 100.00%
# Epoch [49/100], Loss: 0.0274, Accuracy: 100.00%
# Epoch [50/100], Loss: 0.0265, Accuracy: 100.00%
# Epoch [51/100], Loss: 0.0252, Accuracy: 100.00%
# Epoch [52/100], Loss: 0.0256, Accuracy: 100.00%
# Epoch [53/100], Loss: 0.0246, Accuracy: 100.00%
# Epoch [54/100], Loss: 0.0239, Accuracy: 100.00%
# Epoch [55/100], Loss: 0.0233, Accuracy: 100.00%
# Epoch [56/100], Loss: 0.0223, Accuracy: 100.00%
# Epoch [57/100], Loss: 0.0214, Accuracy: 100.00%
# Epoch [58/100], Loss: 0.0210, Accuracy: 100.00%
# Epoch [59/100], Loss: 0.0206, Accuracy: 100.00%
# Epoch [60/100], Loss: 0.0205, Accuracy: 100.00%
# Epoch [61/100], Loss: 0.0219, Accuracy: 100.00%
# Epoch [62/100], Loss: 0.0287, Accuracy: 99.28%
# Epoch [63/100], Loss: 0.0235, Accuracy: 100.00%
# Epoch [64/100], Loss: 0.0237, Accuracy: 100.00%
# Epoch [65/100], Loss: 0.0211, Accuracy: 100.00%
# Epoch [66/100], Loss: 0.0211, Accuracy: 100.00%
# Epoch [67/100], Loss: 0.0188, Accuracy: 100.00%
# Epoch [68/100], Loss: 0.0184, Accuracy: 100.00%
# Epoch [69/100], Loss: 0.0181, Accuracy: 100.00%
# Epoch [70/100], Loss: 0.0170, Accuracy: 100.00%
# Epoch [71/100], Loss: 0.0172, Accuracy: 100.00%
# Epoch [72/100], Loss: 0.0169, Accuracy: 100.00%
# Epoch [73/100], Loss: 0.0185, Accuracy: 100.00%
# Epoch [74/100], Loss: 0.0182, Accuracy: 100.00%
# Epoch [75/100], Loss: 0.0166, Accuracy: 100.00%
# Epoch [76/100], Loss: 0.0152, Accuracy: 100.00%
# Epoch [77/100], Loss: 0.0150, Accuracy: 100.00%
# Epoch [78/100], Loss: 0.0143, Accuracy: 100.00%
# Epoch [79/100], Loss: 0.0142, Accuracy: 100.00%
# Epoch [80/100], Loss: 0.0139, Accuracy: 100.00%
# Epoch [81/100], Loss: 0.0131, Accuracy: 100.00%
# Epoch [82/100], Loss: 0.0132, Accuracy: 100.00%
# Epoch [83/100], Loss: 0.0129, Accuracy: 100.00%
# Epoch [84/100], Loss: 0.0127, Accuracy: 100.00%
# Epoch [85/100], Loss: 0.0125, Accuracy: 100.00%
# Epoch [86/100], Loss: 0.0121, Accuracy: 100.00%
# Epoch [87/100], Loss: 0.0120, Accuracy: 100.00%
# Epoch [88/100], Loss: 0.0120, Accuracy: 100.00%
# Epoch [89/100], Loss: 0.0120, Accuracy: 100.00%
# Epoch [90/100], Loss: 0.0119, Accuracy: 100.00%
# Epoch [91/100], Loss: 0.0117, Accuracy: 100.00%
# Epoch [92/100], Loss: 0.0111, Accuracy: 100.00%
# Epoch [93/100], Loss: 0.0112, Accuracy: 100.00%
# Epoch [94/100], Loss: 0.0109, Accuracy: 100.00%
# Epoch [95/100], Loss: 0.0111, Accuracy: 100.00%
# Epoch [96/100], Loss: 0.0105, Accuracy: 100.00%
# Epoch [97/100], Loss: 0.0104, Accuracy: 100.00%
# Epoch [98/100], Loss: 0.0108, Accuracy: 100.00%
# Epoch [99/100], Loss: 0.0100, Accuracy: 100.00%
# Epoch [100/100], Loss: 0.0099, Accuracy: 100.00%
# Eğitim tamamlandı!

# %%
torch.save(model.state_dict(), "speaker_identification_model.pth")
print("Model kaydedildi!")
# Out:
# Model kaydedildi!
